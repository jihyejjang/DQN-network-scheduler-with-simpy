# %%
import simpy
import pandas as pd
import numpy as np 
#from collections import namedtuple
#from recordtype import recordtype
import random 
import matplotlib
matplotlib.use('TkAgg')
import matplotlib.pyplot as plt
#from prettytable import PrettyTable
#get_ipython().magic('matplotlib inline')
#from keras.models import Sequential
#from keras.layers import Dense, Dropout
#from keras.optimizers import Adam 
from collections import deque 
from itertools import product
import math
from DQN import DQN
        
def episode(env,DQN,Tsc,Tfu,allowed_actions): #pacing rate가 각 flow에게 할당
    global action
    global state
    global request
    global flow_success
    fs=request['filesize']
    cnt=1
    c=0
    dqn_agent = DQN()
    while True: #Simularion time 동안 episode를 반복한다
        print ("-------------")
        print("Episode start",cnt)
        print ("")
        first_action=1 #new action의 경우 학습데이터에 추가하지 않음
        
        #1개의 에피소드는 모든 filesize가 0이 될때까지 실행
        while ((request['filesize'][0]!=0)or(request['filesize'][1]!=0)or(request['filesize'][2]!=0)):#모두 전송이 완료될 때 까지
            c+=1
            try: #state = filesize/deadline
                state=[int((request['filesize'][s]/request['deadline'][s])/102) for s in range(len(request['sources']))]
            except:#deadline이 0인 source가 존재하는 경우 (0 division 에러)
                for s in range(len(sources)):#deadline이 0이 아닌 source는 그대로
                    if (request['deadline'][s] != 0):
                        state[s]= int((request['filesize'][s]/request['deadline'][s])/102)
                    else:#deadline이 0인 source의 state는 0
                        state[s]=0
            
            print ("state",state)
            
            if (first_action==1): #New state-action policy를 EDF방식으로 (가장 deadline이 시급한)     
                action=[0,0,0]
                index=np.argmin(request['deadline']) #deadline 최소인 source의 index
                action[index]=10 #bottleneck capacity
                
            else: 
                action,p=dqn_agent.choose_action(state,allowed_actions) #DQN에 의한 액션선택
                pexp.append(p)
                
            #TSC를 for문으로 하면 너무 오래걸림
            #TSC시작
            for s in range(len(sources)): #각 source에 대해 반복
                request['filesize'][s]=max([request['filesize'][s]-int(Tsc*action[s]*102),0]) #음수 X 1024/10
                request['deadline'][s]=max(request['deadline'][s]-Tsc,0) #음수 X, deadline은 Tsc만큼 감소
                # deadline을 양수로 해야하는 이유 > 음수면  value가 1로 할당됨
                if ((request['filesize'][s]==0) and (request['value'][s]==None)): #아직 완료되지 않았던 flow가 전송이 완료되면?
                    #print ("s{}의 전송이 완료됨".format(s))
                    if (request['deadline'][s]!=0): #기간 안에 전송되면?
                        request['value'][s]=1 #value를 1로 변경
                        flow_success.append(1)
                        print ("s{}의 전송이 deadline 안에 완료됨".format(s))
                    else: #기간안에 전송된게 아니라면(value초기값은 None)
                        request['value'][s]=0
                        flow_success.append(0)
                        print ("s{}의 전송이 deadline을 지나 완료됨".format(s))



#             for i in range(Tsc):#Scheduling interval 시작
#                 for s in range(len(sources)): #각 source에 대해 반복
#                     request['filesize'][s]=max([request['filesize'][s]-int(action[s]*102),0]) #음수 X 1024/10
#                     request['deadline'][s]=max(request['deadline'][s]-1,0) #음수 X, deadline은 Tsc만큼 감소
#                     # deadline을 양수로 해야하는 이유 > 음수면  value가 1로 할당됨
#                     if ((request['filesize'][s]==0) and (request['value'][s]==None)): #아직 완료되지 않았던 flow가 전송이 완료되면?
#                         #print ("s{}의 전송이 완료됨".format(s))
#                         if (request['deadline'][s]!=0): #기간 안에 전송되면?
#                             request['value'][s]=1 #value를 1로 변경
#                             flow_success.append(1)
#                             #print ("s{}의 전송이 deadline 안에 완료됨".format(s))
#                         else: #기간안에 전송된게 아니라면(value초기값은 None)
#                             request['value'][s]=0
#                             flow_success.append(0)
#                             #print ("s{}의 전송이 deadline을 지나 완료됨".format(s))
                            
            #scheduling interval이 끝나고 return                
            yield env.timeout(Tfu*Tsc)# Tfu(1초)마다 위 과정 실행
            
            
            
            print ("action", action)
#             print ("")
#             print ("source 0 :",request['value'][0])
#             print ("")
#             print ("source 1 :",request['value'][1])
#             print ("")
#             print ("source 2 :",request['value'][2])
        
            #모든 전송이 완료된 후 next_state는 고려할 필요 없음: 아래 학습과정 생략
            if ((request['filesize'][0]==0)and(request['filesize'][1]==0)and(request['filesize'][2]==0)):
                continue
                
            try: 
                next_state=[int((request['filesize'][s]/request['deadline'][s])/102) for s in range(len(request['sources']))]
            except:#deadline이 0인 경우 error
                for s in range(len(sources)):
                    if (request['deadline'][s] != 0):
                        next_state[s]= int((request['filesize'][s]/request['deadline'][s])/102)
                    else:
                        next_state[s]=0
                        
            #print(next_state)
                        
            # build your reward function 리워드 방정식 입력
            reward = sum((np.max(request['deadline'])-request['deadline'])*action*102)
            cur_state = state 
            action = action
            new_state = next_state 
            #new_action = next_allowed_actions
            reward = reward
            #done = done
            
            if (first_action==0): # 첫번쨰 선택 액션이 아닌경우에만 학습
                dqn_agent.remember(cur_state, action, reward, new_state) #새로운 state로 설정해주고 기존state저장
                mse_loss.append(dqn_agent.replay(allowed_actions))#학습, loss 저장
                dqn_agent.train_target()
            
            first_action=0 

        for i in range(len(sources)):
            if (request['value'][i]==1):
                print ("source {} 전송완료".format(i))
            else:
                print ("source {} deadine 충족하지 못함".format(i))
        
        print("모두 전송 완료")

        filesize=[random.randrange(10,50)*1024 for source in range(len(sources))] #단위 Mb
        deadline=[int(filesize[source]/307) for source in range(len(sources))] #sum_rmin이  9
        request = {
            'sources' : sources,
            'destinations' : destinations, 
            'filesize' : filesize, #단위는 Gbps
            'deadline' : deadline,
            'value' : [None for source in sources] #아직 전송되지 않았으면 None, 제시간에 전송되었으면 1, 제시간에 전송되지 않았으면 0
        }#다음 episode를 위해 request 생성

        state=[0,0,0]#초기 state
        action=[0,0,0]#초기 action ->고칠것
        print ("episode end")
        print("-----------------")
        cnt+=1
    
    dqn_agent.save_model("policy_network.h5")
    
    


#한 번의 에피소드 프로세스
#N개의 source에서 동시에 request를 발생시키면 시작됨
#끝나는 기점은 모든 flow가 전송이 완료되는 시점
#랜덤으로 filesize를 생성, deadline도 랜덤으로 생성
env = simpy.Environment()

mse_loss=[] #episode의 진행에 따른 mse_loss의 변화율 graph
flow_success=[] #episode의 진행에 따른 flow_success rate
pexp=[] #action choice 진행에 따른 pexp 변화

state=[0,0,0]#초기 state
action=[0,0,0]#초기 action ->고칠것
Tsc=10 #scheduling interval을 구성하는 flow update interval의 수
Tfu=0.1 #flow update interval의 시간단위(0.1초로 가정)
sources = ['s0', 's1', 's2']
destinations = ['d0', 'd1', 'd2']
filesize=[random.randrange(10,50)*1024 for source in range(len(sources))] #단위 Mb
deadline=[int(filesize[source]/307) for source in range(len(sources))] #sum_rmin이  9
request = {
    'sources' : sources,
    'destinations' : destinations, 
    'filesize' : filesize, #단위는 Mbps
    'deadline' : deadline,
    'value' : [None for source in sources] #아직 전송되지 않았으면 None, 제시간에 전송되었으면 1, 제시간에 전송되지 않았으면 0
}

A=list(range(11))
B=list(range(11))
C=list(range(11)) 
allowed_actions=[] #합이 10이 되는 0~10까지의 수 조합
for i in list(product(*(A,B,C))):
    if sum(list(i))==10:
        allowed_actions.append(i) #d는 66개의 조합
        
#print ("action", action)
#print ("")
# print ("source 0 전송할 file:",request['filesize'][0])
# print ("")
# print ("source 1 전송할 file:",request['filesize'][1])
# print ("")
# print ("source 2 전송할 file:",request['filesize'][2])

# print ("source 0의 min_rate:",math.ceil(request['filesize'][0]/request['deadline'][0]))
# print("")
# print ("source 1의 min_rate:",math.ceil(request['filesize'][1]/request['deadline'][1]))
# print("")
# print ("source 0의 min_rate:",math.ceil(request['filesize'][2]/request['deadline'][2]))


env.process(episode(env,DQN,Tsc,Tfu,allowed_actions))
env.run(until=100000)#10만 초 동안 가동
print("종료")

#print (mse_loss)
#print (flow_success)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\user\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# WARNING:tensorflow:From C:\Users\user\anaconda3\lib\site-packages\tensorflow\python\ops\init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# -------------
# Episode start 1
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 1]
# 0.999
# 1
# random action
# action (5, 4, 1)
# update weights
# state [3, 3, 2]
# 0.999
# 2
# random action
# action (2, 1, 7)
# update weights
# state [3, 3, 0]
# 0.999
# 3
# random action
# action (1, 8, 1)
# update weights
# state [3, 2, 0]
# 0.999
# 4
# random action
# s2의 전송이 deadline 안에 완료됨
# action (2, 3, 5)
# update weights
# state [3, 2, 0]
# 0.999
# 5
# random action
# action (3, 0, 7)
# update weights
# state [3, 3, 0]
# 0.999
# 6
# random action
# action (3, 0, 7)
# update weights
# state [3, 4, 0]
# 0.999
# 7
# random action
# action (1, 1, 8)
# update weights
# state [4, 5, 0]
# 0.999
# 8
# random action
# action (4, 6, 0)
# update weights
# state [4, 4, 0]
# 0.999
# 9
# random action
# action (2, 7, 1)
# update weights
# state [5, 3, 0]
# 0.999
# 10
# random action
# action (8, 0, 2)
# update weights
# state [4, 8, 0]
# 0.999
# 11
# random action
# action (5, 2, 3)
# update weights
# state [3, 0, 0]
# 0.999
# 12
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (7, 0, 3)
# update weights
# state [0, 0, 0]
# 0.999
# 13
# random action
# action (9, 1, 0)
# update weights
# state [0, 0, 0]
# 0.999
# 14
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (2, 5, 3)
# source 0 deadine 충족하지 못함
# source 1 deadine 충족하지 못함
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 2
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 0, 3]
# 0.999
# 15
# random action
# s1의 전송이 deadline 안에 완료됨
# action (1, 5, 4)
# update weights
# state [3, 0, 3]
# 0.999
# 16
# random action
# action (6, 0, 4)
# update weights
# state [3, 0, 3]
# 0.999
# 17
# random action
# action (1, 2, 7)
# update weights
# state [3, 0, 2]
# 0.999
# 18
# random action
# action (7, 3, 0)
# update weights
# state [3, 0, 3]
# 0.999
# 19
# random action
# action (2, 1, 7)
# update weights
# state [3, 0, 0]
# 0.999
# 20
# random action
# action (10, 0, 0)
# update weights
# state [1, 0, 1]
# 0.999
# 21
# random action
# action (5, 5, 0)
# update weights
# state [0, 0, 0]
# 0.999
# 22
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (3, 0, 7)
# update weights
# state [0, 0, 0]
# 0.999
# 23
# random action
# s0의 전송이 deadline 안에 완료됨
# action (5, 4, 1)
# source 0 전송완료
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 3
#
# state [3, 3, 3]
# action [10, 0, 0]
# state [2, 3, 3]
# 0.999
# 24
# random action
# action (4, 6, 0)
# update weights
# state [1, 3, 3]
# 0.999
# 25
# random action
# action (9, 1, 0)
# update weights
# state [0, 3, 3]
# 0.999
# 26
# random action
# action (0, 3, 7)
# update weights
# state [0, 3, 3]
# 0.999
# 27
# random action
# s0의 전송이 deadline 안에 완료됨
# action (7, 3, 0)
# update weights
# state [0, 3, 4]
# 0.999
# 28
# random action
# action (0, 5, 5)
# update weights
# state [0, 3, 3]
# 0.999
# 29
# random action
# action (1, 2, 7)
# update weights
# state [0, 3, 3]
# 0.999
# 30
# random action
# action (2, 5, 3)
# update weights
# state [0, 2, 3]
# 0.999
# 31
# random action
# action (2, 8, 0)
# update weights
# state [0, 0, 4]
# 0.999
# 32
# random action
# action (8, 1, 1)
# update weights
# state [0, 0, 6]
# 0.999
# 33
# random action
# action (10, 0, 0)
# update weights
# state [0, 0, 10]
# 0.999
# 34
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (3, 5, 2)
# update weights
# state [0, 0, 40]
# 0.999
# 35
# random action
# action (1, 5, 4)
# update weights
# state [0, 0, 0]
# 0.999
# 36
# random action
# action (1, 3, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 37
# random action
# action (4, 4, 2)
# update weights
# state [0, 0, 0]
# 0.999
# 38
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (5, 1, 4)
# source 0 전송완료
# source 1 deadine 충족하지 못함
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 4
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 2, 3]
# 0.999
# 39
# random action
# action (0, 5, 5)
# update weights
# state [3, 1, 3]
# 0.999
# 40
# random action
# action (1, 0, 9)
# update weights
# state [3, 2, 2]
# 0.999
# 41
# random action
# action (2, 5, 3)
# update weights
# state [4, 1, 2]
# 0.999
# 42
# random action
# action (10, 0, 0)
# update weights
# state [3, 1, 2]
# 0.999
# 43
# random action
# action (4, 2, 4)
# update weights
# state [3, 1, 2]
# 0.999
# 44
# random action
# action (10, 0, 0)
# update weights
# state [1, 2, 3]
# 0.999
# 45
# random action
# action (8, 1, 1)
# update weights
# state [0, 3, 3]
# 0.999
# 46
# random action
# s0의 전송이 deadline 안에 완료됨
# action (2, 1, 7)
# update weights
# state [0, 13, 2]
# 0.999
# 47
# random action
# action (6, 2, 2)
# update weights
# state [0, 0, 2]
# 0.999
# 48
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (5, 5, 0)
# update weights
# state [0, 0, 3]
# 0.999
# 49
# random action
# action (0, 4, 6)
# update weights
# state [0, 0, 2]
# 0.999
# 50
# random action
# s2의 전송이 deadline 안에 완료됨
# action (1, 1, 8)
# source 0 전송완료
# source 1 deadine 충족하지 못함
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 5
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 1, 3]
# 0.999
# 51
# random action
# action (4, 0, 6)
# update weights
# state [3, 1, 3]
# 0.999
# 52
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 7, 3)
# update weights
# state [4, 0, 3]
# 0.999
# 53
# random action
# action (1, 9, 0)
# update weights
# state [6, 0, 3]
# 0.999
# 54
# random action
# action (9, 0, 1)
# update weights
# state [4, 0, 3]
# 0.999
# 55
# random action
# action (3, 3, 4)
# update weights
# state [0, 0, 3]
# 0.999
# 56
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (6, 1, 3)
# update weights
# state [0, 0, 3]
# 0.999
# 57
# random action
# action (0, 10, 0)
# update weights
# state [0, 0, 4]
# 0.999
# 58
# random action
# action (4, 2, 4)
# update weights
# state [0, 0, 4]
# 0.999
# 59
# random action
# action (0, 1, 9)
# update weights
# state [0, 0, 3]
# 0.999
# 60
# random action
# action (9, 0, 1)
# update weights
# state [0, 0, 3]
# 0.999
# 61
# random action
# action (0, 1, 9)
# update weights
# state [0, 0, 1]
# 0.999
# 62
# random action
# action (1, 7, 2)
# update weights
# state [0, 0, 0]
# 0.999
# 63
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (5, 4, 1)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 6
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 0, 3]
# 0.999
# 64
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 3, 7)
# update weights
# state [3, 0, 2]
# 0.999
# 65
# random action
# action (6, 1, 3)
# update weights
# state [3, 0, 2]
# 0.999
# 66
# random action
# action (3, 4, 3)
# update weights
# state [3, 0, 2]
# 0.999
# 67
# random action
# action (0, 0, 10)
# update weights
# state [3, 0, 2]
# 0.999
# 68
# random action
# action (8, 0, 2)
# update weights
# state [3, 0, 2]
# 0.999
# 69
# random action
# action (1, 7, 2)
# update weights
# state [3, 0, 2]
# 0.999
# 70
# random action
# action (0, 6, 4)
# update weights
# state [4, 0, 1]
# 0.999
# 71
# random action
# action (4, 5, 1)
# update weights
# state [4, 0, 2]
# 0.999
# 72
# random action
# action (3, 6, 1)
# update weights
# state [4, 0, 2]
# 0.999
# 73
# random action
# action (1, 2, 7)
# update weights
# state [6, 0, 0]
# 0.999
# 74
# random action
# action (2, 7, 1)
# update weights
# state [11, 0, 0]
# 0.999
# 75
# random action
# action (0, 10, 0)
# update weights
# state [0, 0, 1]
# 0.999
# 76
# random action
# action (7, 3, 0)
# update weights
# state [0, 0, 7]
# 0.999
# 77
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (0, 5, 5)
# update weights
# state [0, 0, 0]
# 0.999
# 78
# random action
# action (1, 1, 8)
# update weights
# state [0, 0, 0]
# 0.999
# 79
# random action
# action (0, 4, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 80
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (4, 1, 5)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 7
#
# state [3, 3, 3]
# action [10, 0, 0]
# state [2, 3, 3]
# 0.999
# 81
# random action
# action (0, 1, 9)
# update weights
# state [2, 3, 2]
# 0.999
# 82
# random action
# action (2, 1, 7)
# update weights
# state [2, 3, 2]
# 0.999
# 83
# random action
# action (4, 4, 2)
# update weights
# state [2, 3, 2]
# 0.999
# 84
# random action
# action (2, 4, 4)
# update weights
# state [2, 3, 2]
# 0.999
# 85
# random action
# action (2, 7, 1)
# update weights
# state [2, 3, 2]
# 0.999
# 86
# random action
# action (2, 6, 2)
# update weights
# state [2, 2, 2]
# 0.999
# 87
# random action
# action (0, 3, 7)
# update weights
# state [4, 2, 1]
# 0.999
# 88
# random action
# action (3, 1, 6)
# update weights
# state [6, 3, 0]
# 0.999
# 89
# random action
# s2의 전송이 deadline 안에 완료됨
# action (2, 4, 4)
# update weights
# state [0, 2, 0]
# 0.999
# 90
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 9, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 91
# random action
# action (1, 2, 7)
# update weights
# state [0, 0, 0]
# 0.999
# 92
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (5, 4, 1)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 8
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 1]
# 0.999
# 93
# random action
# action (4, 0, 6)
# update weights
# state [3, 3, 0]
# 0.999
# 94
# random action
# s2의 전송이 deadline 안에 완료됨
# action (0, 1, 9)
# update weights
# state [3, 4, 0]
# 0.999
# 95
# random action
# action (6, 0, 4)
# update weights
# state [3, 5, 0]
# 0.999
# 96
# random action
# action (3, 1, 6)
# update weights
# state [3, 6, 0]
# 0.999
# 97
# random action
# action (1, 0, 9)
# update weights
# state [4, 8, 0]
# 0.999
# 98
# random action
# action (7, 1, 2)
# update weights
# state [3, 12, 0]
# 0.999
# 99
# random action
# action (0, 8, 2)
# update weights
# state [4, 16, 0]
# 0.999
# 100
# random action
# action (4, 3, 3)
# update weights
# state [5, 0, 0]
# 0.999
# 101
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (7, 2, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 102
# random action
# action (1, 8, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 103
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (5, 4, 1)
# source 0 deadine 충족하지 못함
# source 1 deadine 충족하지 못함
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 9
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 0]
# 0.999
# 104
# random action
# action (7, 3, 0)
# update weights
# state [2, 3, 1]
# 0.999
# 105
# random action
# action (2, 6, 2)
# update weights
# state [3, 3, 0]
# 0.999
# 106
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (2, 3, 5)
# update weights
# state [3, 3, 0]
# 0.999
# 107
# random action
# action (7, 2, 1)
# update weights
# state [2, 3, 0]
# 0.999
# 108
# random action
# action (0, 0, 10)
# update weights
# state [3, 3, 0]
# 0.999
# 109
# random action
# action (2, 1, 7)
# update weights
# state [3, 4, 0]
# 0.999
# 110
# random action
# action (5, 5, 0)
# update weights
# state [1, 3, 0]
# 0.999
# 111
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (7, 2, 1)
# update weights
# state [0, 4, 0]
# 0.999
# 112
# random action
# action (2, 3, 5)
# update weights
# state [0, 5, 0]
# 0.999
# 113
# random action
# action (9, 1, 0)
# update weights
# state [0, 8, 0]
# 0.999
# 114
# random action
# action (0, 8, 2)
# update weights
# state [0, 10, 0]
# 0.999
# 115
# random action
# action (0, 3, 7)
# update weights
# state [0, 0, 0]
# 0.999
# 116
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (8, 2, 0)
# source 0 deadine 충족하지 못함
# source 1 deadine 충족하지 못함
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 10
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 1]
# 0.999
# 117
# random action
# action (7, 3, 0)
# update weights
# state [2, 3, 1]
# 0.999
# 118
# random action
# action (3, 6, 1)
# update weights
# state [2, 3, 2]
# 0.999
# 119
# random action
# action (5, 2, 3)
# update weights
# state [2, 3, 1]
# 0.999
# 120
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 8, 2)
# update weights
# state [3, 0, 0]
# 0.999
# 121
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (2, 3, 5)
# update weights
# state [3, 0, 0]
# 0.999
# 122
# random action
# action (6, 3, 1)
# update weights
# state [1, 0, 0]
# 0.999
# 123
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (5, 3, 2)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 11
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 1, 3]
# 0.999
# 124
# random action
# action (0, 3, 7)
# update weights
# state [3, 0, 2]
# 0.999
# 125
# random action
# s1의 전송이 deadline 안에 완료됨
# action (4, 3, 3)
# update weights
# state [3, 0, 2]
# 0.999
# 126
# random action
# action (4, 1, 5)
# update weights
# state [3, 0, 2]
# 0.999
# 127
# random action
# action (8, 0, 2)
# update weights
# state [2, 0, 2]
# 0.999
# 128
# random action
# action (3, 1, 6)
# update weights
# state [2, 0, 1]
# 0.999
# 129
# random action
# action (7, 2, 1)
# update weights
# state [2, 0, 1]
# 0.999
# 130
# random action
# action (0, 9, 1)
# update weights
# state [2, 0, 2]
# 0.999
# 131
# random action
# s2의 전송이 deadline 안에 완료됨
# action (1, 1, 8)
# update weights
# state [3, 0, 0]
# 0.999
# 132
# random action
# action (9, 0, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 133
# random action
# action (2, 2, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 134
# random action
# s0의 전송이 deadline 안에 완료됨
# action (5, 4, 1)
# source 0 전송완료
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 12
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 2, 3]
# 0.999
# 135
# random action
# action (0, 6, 4)
# update weights
# state [3, 1, 3]
# 0.999
# 136
# random action
# action (5, 5, 0)
# update weights
# state [3, 1, 3]
# 0.999
# 137
# random action
# action (0, 2, 8)
# update weights
# state [3, 1, 3]
# 0.999
# 138
# random action
# action (3, 6, 1)
# update weights
# state [3, 0, 3]
# 0.999
# 139
# random action
# s1의 전송이 deadline 안에 완료됨
# action (3, 5, 2)
# update weights
# state [3, 0, 3]
# 0.999
# 140
# random action
# action (1, 4, 5)
# update weights
# state [4, 0, 3]
# 0.999
# 141
# random action
# action (7, 2, 1)
# update weights
# state [3, 0, 3]
# 0.999
# 142
# random action
# action (0, 0, 10)
# update weights
# state [4, 0, 2]
# 0.999
# 143
# random action
# action (0, 6, 4)
# update weights
# state [5, 0, 1]
# 0.999
# 144
# random action
# action (3, 5, 2)
# update weights
# state [6, 0, 1]
# 0.999
# 145
# random action
# action (1, 7, 2)
# update weights
# state [9, 0, 1]
# 0.999
# 146
# random action
# action (4, 6, 0)
# update weights
# state [15, 0, 3]
# 0.999
# 147
# random action
# s2의 전송이 deadline 안에 완료됨
# action (1, 2, 7)
# update weights
# state [0, 0, 0]
# 0.999
# 148
# random action
# action (4, 0, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 149
# random action
# action (3, 4, 3)
# update weights
# state [0, 0, 0]
# 0.999
# 150
# random action
# action (3, 6, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 151
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (9, 1, 0)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 13
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 0, 3]
# 0.999
# 152
# random action
# action (10, 0, 0)
# update weights
# state [2, 0, 4]
# 0.999
# 153
# random action
# s1의 전송이 deadline 안에 완료됨
# action (4, 2, 4)
# update weights
# state [2, 0, 4]
# 0.999
# 154
# random action
# action (6, 2, 2)
# update weights
# state [1, 0, 5]
# 0.999
# 155
# random action
# action (6, 2, 2)
# update weights
# state [0, 0, 8]
# 0.999
# 156
# random action
# action (5, 5, 0)
# update weights
# state [0, 0, 36]
# 0.999
# 157
# random action
# s0의 전송이 deadline 안에 완료됨
# action (2, 4, 4)
# update weights
# state [0, 0, 0]
# 0.999
# 158
# random action
# action (7, 3, 0)
# update weights
# state [0, 0, 0]
# 0.999
# 159
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (0, 0, 10)
# source 0 전송완료
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 14
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 0]
# 0.999
# 160
# random action
# s2의 전송이 deadline 안에 완료됨
# action (8, 0, 2)
# update weights
# state [2, 3, 0]
# 0.999
# 161
# random action
# action (0, 4, 6)
# update weights
# state [3, 3, 0]
# 0.999
# 162
# random action
# action (6, 4, 0)
# update weights
# state [2, 3, 0]
# 0.999
# 163
# random action
# action (1, 7, 2)
# update weights
# state [3, 3, 0]
# 0.999
# 164
# random action
# action (2, 5, 3)
# update weights
# state [3, 2, 0]
# 0.999
# 165
# random action
# action (5, 0, 5)
# update weights
# state [2, 3, 0]
# 0.999
# 166
# random action
# action (3, 3, 4)
# update weights
# state [2, 3, 0]
# 0.999
# 167
# random action
# action (6, 2, 2)
# update weights
# state [0, 10, 0]
# 0.999
# 168
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (0, 6, 4)
# update weights
# state [0, 0, 0]
# 0.999
# 169
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (5, 0, 5)
# source 0 deadine 충족하지 못함
# source 1 deadine 충족하지 못함
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 15
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 1, 3]
# 0.999
# 170
# random action
# action (0, 6, 4)
# update weights
# state [4, 0, 3]
# 0.999
# 171
# random action
# action (5, 1, 4)
# update weights
# state [4, 0, 3]
# 0.999
# 172
# random action
# action (10, 0, 0)
# update weights
# state [2, 1, 4]
# 0.999
# 173
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 4, 6)
# update weights
# state [3, 0, 3]
# 0.999
# 174
# random action
# action (0, 7, 3)
# update weights
# state [6, 0, 3]
# 0.999
# 175
# random action
# action (2, 7, 1)
# update weights
# state [0, 0, 6]
# 0.999
# 176
# random action
# action (3, 1, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 177
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (1, 6, 3)
# update weights
# state [0, 0, 0]
# 0.999
# 178
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (7, 3, 0)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 16
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 1, 3]
# 0.999
# 179
# random action
# action (0, 2, 8)
# update weights
# state [3, 1, 2]
# 0.999
# 180
# random action
# action (5, 2, 3)
# update weights
# state [3, 0, 2]
# 0.999
# 181
# random action
# s1의 전송이 deadline 안에 완료됨
# action (4, 4, 2)
# update weights
# state [3, 0, 2]
# 0.999
# 182
# random action
# action (10, 0, 0)
# update weights
# state [2, 0, 3]
# 0.999
# 183
# random action
# action (4, 2, 4)
# update weights
# state [2, 0, 3]
# 0.999
# 184
# random action
# action (1, 0, 9)
# update weights
# state [2, 0, 2]
# 0.999
# 185
# random action
# action (3, 1, 6)
# update weights
# state [2, 0, 1]
# 0.999
# 186
# random action
# action (1, 2, 7)
# update weights
# state [2, 0, 0]
# 0.999
# 187
# random action
# s2의 전송이 deadline 안에 완료됨
# action (5, 4, 1)
# update weights
# state [2, 0, 0]
# 0.999
# 188
# random action
# action (1, 8, 1)
# update weights
# state [2, 0, 0]
# 0.999
# 189
# random action
# action (8, 2, 0)
# update weights
# state [1, 0, 0]
# 0.999
# 190
# random action
# action (1, 2, 7)
# update weights
# state [1, 0, 0]
# 0.999
# 191
# random action
# action (4, 3, 3)
# update weights
# state [0, 0, 0]
# 0.999
# 192
# random action
# s0의 전송이 deadline 안에 완료됨
# action (4, 5, 1)
# source 0 전송완료
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 17
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 2]
# 0.999
# 193
# random action
# action (0, 6, 4)
# update weights
# state [3, 3, 1]
# 0.999
# 194
# random action
# action (1, 0, 9)
# update weights
# state [3, 3, 0]
# 0.999
# 195
# random action
# s2의 전송이 deadline 안에 완료됨
# action (3, 1, 6)
# update weights
# state [3, 3, 0]
# 0.999
# 196
# random action
# action (7, 3, 0)
# update weights
# state [3, 3, 0]
# 0.999
# 197
# random action
# action (5, 2, 3)
# update weights
# state [3, 3, 0]
# 0.999
# 198
# random action
# action (1, 2, 7)
# update weights
# state [3, 3, 0]
# 0.999
# 199
# random action
# action (4, 5, 1)
# update weights
# state [3, 3, 0]
# 0.999
# 200
# random action
# action (2, 7, 1)
# update weights
# state [3, 3, 0]
# 0.999
# 201
# random action
# action (3, 6, 1)
# update weights
# state [3, 2, 0]
# 0.999
# 202
# random action
# action (3, 1, 6)
# update weights
# state [3, 3, 0]
# 0.999
# 203
# random action
# action (1, 7, 2)
# update weights
# state [4, 1, 0]
# 0.999
# 204
# random action
# action (2, 6, 2)
# update weights
# state [5, 0, 0]
# 0.999
# 205
# random action
# action (2, 0, 8)
# update weights
# state [8, 0, 0]
# 0.999
# 206
# random action
# s1의 전송이 deadline 안에 완료됨
# action (4, 5, 1)
# update weights
# state [15, 0, 0]
# 0.999
# 207
# random action
# action (0, 9, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 208
# random action
# action (3, 6, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 209
# random action
# action (1, 3, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 210
# random action
# action (5, 5, 0)
# update weights
# state [0, 0, 0]
# 0.999
# 211
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (3, 0, 7)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 18
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 2, 3]
# 0.999
# 212
# random action
# action (4, 4, 2)
# update weights
# state [3, 1, 3]
# 0.999
# 213
# random action
# action (1, 2, 7)
# update weights
# state [3, 1, 3]
# 0.999
# 214
# random action
# action (2, 2, 6)
# update weights
# state [3, 1, 2]
# 0.999
# 215
# random action
# action (8, 0, 2)
# update weights
# state [3, 2, 2]
# 0.999
# 216
# random action
# action (0, 1, 9)
# update weights
# state [3, 2, 1]
# 0.999
# 217
# random action
# action (1, 1, 8)
# update weights
# state [4, 4, 0]
# 0.999
# 218
# random action
# s1의 전송이 deadline을 지나 완료됨
# action (2, 6, 2)
# update weights
# state [4, 0, 0]
# 0.999
# 219
# random action
# s2의 전송이 deadline 안에 완료됨
# action (1, 0, 9)
# update weights
# state [5, 0, 0]
# 0.999
# 220
# random action
# action (0, 9, 1)
# update weights
# state [8, 0, 0]
# 0.999
# 221
# random action
# action (3, 1, 6)
# update weights
# state [14, 0, 0]
# 0.999
# 222
# random action
# action (2, 2, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 223
# random action
# action (2, 3, 5)
# update weights
# state [0, 0, 0]
# 0.999
# 224
# random action
# action (1, 0, 9)
# update weights
# state [0, 0, 0]
# 0.999
# 225
# random action
# action (2, 2, 6)
# update weights
# state [0, 0, 0]
# 0.999
# 226
# random action
# action (6, 4, 0)
# update weights
# state [0, 0, 0]
# 0.999
# 227
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (3, 5, 2)
# source 0 deadine 충족하지 못함
# source 1 deadine 충족하지 못함
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 19
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 2]
# 0.999
# 228
# random action
# action (3, 5, 2)
# update weights
# state [3, 3, 2]
# 0.999
# 229
# random action
# action (4, 1, 5)
# update weights
# state [3, 3, 1]
# 0.999
# 230
# random action
# action (6, 1, 3)
# update weights
# state [2, 3, 1]
# 0.999
# 231
# random action
# action (3, 7, 0)
# update weights
# state [2, 3, 1]
# 0.999
# 232
# random action
# action (8, 1, 1)
# update weights
# state [1, 3, 1]
# 0.999
# 233
# random action
# s0의 전송이 deadline 안에 완료됨
# action (8, 0, 2)
# update weights
# state [0, 3, 1]
# 0.999
# 234
# random action
# s2의 전송이 deadline 안에 완료됨
# action (3, 1, 6)
# update weights
# state [0, 4, 0]
# 0.999
# 235
# random action
# action (0, 8, 2)
# update weights
# state [0, 3, 0]
# 0.999
# 236
# random action
# action (1, 9, 0)
# update weights
# state [0, 2, 0]
# 0.999
# 237
# random action
# action (0, 2, 8)
# update weights
# state [0, 2, 0]
# 0.999
# 238
# random action
# action (10, 0, 0)
# update weights
# state [0, 3, 0]
# 0.999
# 239
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 6, 4)
# source 0 전송완료
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 20
#
# state [3, 3, 3]
# action [0, 0, 10]
# state [3, 3, 2]
# 0.999
# 240
# random action
# action (0, 9, 1)
# update weights
# state [3, 2, 2]
# 0.999
# 241
# random action
# action (4, 2, 4)
# update weights
# state [3, 2, 2]
# 0.999
# 242
# random action
# action (0, 9, 1)
# update weights
# state [4, 1, 2]
# 0.999
# 243
# random action
# action (0, 8, 2)
# update weights
# state [5, 1, 2]
# 0.999
# 244
# random action
# action (3, 3, 4)
# update weights
# state [5, 0, 2]
# 0.999
# 245
# random action
# s1의 전송이 deadline 안에 완료됨
# action (0, 9, 1)
# update weights
# state [7, 0, 2]
# 0.999
# 246
# random action
# action (1, 5, 4)
# update weights
# state [10, 0, 1]
# 0.999
# 247
# random action
# s2의 전송이 deadline 안에 완료됨
# action (0, 6, 4)
# update weights
# state [17, 0, 0]
# 0.999
# 248
# random action
# action (0, 9, 1)
# update weights
# state [77, 0, 0]
# 0.999
# 249
# random action
# action (6, 3, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 250
# random action
# action (8, 0, 2)
# update weights
# state [0, 0, 0]
# 0.999
# 251
# random action
# action (4, 5, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 252
# random action
# action (1, 7, 2)
# update weights
# state [0, 0, 0]
# 0.999
# 253
# random action
# action (4, 5, 1)
# update weights
# state [0, 0, 0]
# 0.999
# 254
# random action
# s0의 전송이 deadline을 지나 완료됨
# action (5, 1, 4)
# source 0 deadine 충족하지 못함
# source 1 전송완료
# source 2 전송완료
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 21
#
# state [3, 3, 3]
# action [0, 10, 0]
# state [3, 0, 3]
# 0.999
# 255
# random action
# s1의 전송이 deadline 안에 완료됨
# action (4, 3, 3)
# update weights
# state [3, 0, 3]
# 0.999
# 256
# random action
# action (5, 4, 1)
# update weights
# state [3, 0, 3]
# 0.999
# 257
# random action
# action (1, 0, 9)
# update weights
# state [3, 0, 2]
# 0.999
# 258
# random action
# action (2, 4, 4)
# update weights
# state [3, 0, 2]
# 0.999
# 259
# random action
# action (3, 5, 2)
# update weights
# state [3, 0, 2]
# 0.999
# 260
# random action
# action (1, 5, 4)
# update weights
# state [4, 0, 2]
# 0.999
# 261
# random action
# action (6, 4, 0)
# update weights
# state [3, 0, 3]
# 0.999
# 262
# random action
# action (5, 3, 2)
# update weights
# state [3, 0, 4]
# 0.999
# 263
# random action
# action (1, 9, 0)
# update weights
# state [4, 0, 20]
# 0.999
# 264
# random action
# s0의 전송이 deadline 안에 완료됨
# action (7, 1, 2)
# update weights
# state [0, 0, 0]
# 0.999
# 265
# random action
# s2의 전송이 deadline을 지나 완료됨
# action (0, 5, 5)
# source 0 전송완료
# source 1 전송완료
# source 2 deadine 충족하지 못함
# 모두 전송 완료
# episode end
# -----------------
# -------------
# Episode start 22
#
# state [3, 3, 3]
# action [10, 0, 0]
# state [2, 3, 3]
# 0.999
# 266
# random action
# action (1, 3, 6)
# update weights
# state [2, 3, 3]
# 0.999
# 267
# random action
# action (9, 0, 1)
# update weights
# state [0, 3, 3]
# 0.999
# 268
# random action
# s0의 전송이 deadline 안에 완료됨
# action (6, 4, 0)
# update weights
# state [0, 3, 3]
# 0.999
# 269
# random action
# action (2, 8, 0)
# update weights
# state [0, 3, 3]
# 0.999
# 270
# random action
# action (8, 0, 2)
# update weights
# state [0, 3, 4]
# 0.999
# 271
# random action
# action (3, 1, 6)
# update weights
# state [0, 3, 3]
# 0.999
# 272
# random action
# action (0, 6, 4)
# update weights
# state [0, 3, 3]
# 0.999
# 273
# random action
# action (4, 3, 3)
# update weights
# state [0, 3, 4]
# 0.999
# 274
# random action
# action (8, 0, 2)
# update weights
# state [0, 3, 4]
# 0.999
# 275
# random action
# action (2, 1, 7)

# %%
len(flow_success) #flow의 개수

# %%
len(mse_loss) #학습수

# %%
rate=[]
m=200
flow_success=np.array(flow_success)
for i in range(int(len(flow_success)/m)):#200개당평균
    print(flow_success[m*i:m*(i+1)])
    rate.append(np.mean(flow_success[m*i:m*(i+1)]))
    print(np.mean(flow_success[m*i:m*(i+1)]))

# %%
from matplotlib import pyplot as plt
import numpy as np

# x = mse_loss #loss그래프

# plt.plot(x)
# plt.show()

x2 = rate #success rate 그래프

plt.plot(x2)
plt.show()

# %% [markdown]
# 1.할 것 : flow update interval을 줄이기 (0.001초?) 어느정도가 적당할 지 교수님꼐여줘보기
#
# 2.reward의 문제점: drem(deadline까지 남아있는 시간)이 가장 짧은 source에 많은 pacing rate를 할당할 수록 높은 reward가 주어지는데, file size를 고려하지 않았다는 문제점이 있다. deadline이 아니라 min rate를 기준으로 해야할듯, 그리고 9:1과 같은 극단적비율로 학습됨
#
# 3.state=0인 경우 filesize=0이란뜻이므로 action을 0으로 할당하는 코드를 짜야함. 문제는 두개의 filesize가 0인경우 어떻게 하냐는것...!!!!! -> state가 0인 index에 따라 action도 0인 allowed_action의 index를 찾고, 그 중 가장 큰 maxQ값을 갖는 action 선택
# bug: source2(3번째 소스)의 state가 0 이면 action을 3,3,4로 할당(원인은 모름)
#
# 4.10만초 동안 가동
#
# 5.deadline이 지나면 음수까지 내려가는 버전으로 돌려보기 > 이것은 안됨... value가 deadline이 0이면 0이되도록 설정했기때문에 deadline이 음수가 되면 value가 1이 됨

# %%
A=list(range(11))
B=list(range(11))
C=list(range(11)) #합이 10이 되는 0~10까지의 수 조합
allowed_actions=[]
for i in list(product(*(A,B,C))):
    if sum(list(i))==10:
        allowed_actions.append(i) #d는 66개의 조합
        
allowed_actions.index((0,10,0))
#print (allowed_actions)

# %%
state=np.array([3,3,3])
np.array(state).reshape(1,state.shape[0])

# %%
#deeplearning없이 시뮬레이션
env = simpy.Environment()

request = {
    'sources' : sources,
    'destinations' : destinations, 
    'filesize' : [random.randrange(50,100) for source in sources], #단위는 Gbps
    'deadline' : [random.randrange(5,30) for source in sources], 
    'value' : [None for source in sources], #아직 전송되지 않았으면 None, 제시간에 전송되었으면 1, 제시간에 전송되지 않았으면 0
}

print ("source 0의 filesize:",request['filesize'][0])
print ("source 1의 filesize:",request['filesize'][1])
print ("source 2의 filesize:",request['filesize'][2])

action=[3,3,4]

Tfu=1

def flowUpdate_interval(env,action,Tfu): #Tsc에서의 action(pacint rate)가 n번의 flow update interval만큼 유지된다.
    #print("flow update interval :",env.now)
    global request
    fs=request['filesize']
    #src=request['sources']
    while True:
        print("flow update interval :",env.now)
        if ((fs[0]!=0)or(fs[1]!=0)or(fs[2]!=0)): #하나라도 0이상으로 남아있으면
            
            print("전송중!영차영차")
            
            for s in range(len(sources)):#0밑으로는 안떨어지게, 전역변수 request의 값을 변경
                request['filesize'][s]=max([request['filesize'][s]-action[s],0]) 
                request['deadline'][s]=max([request['deadline'][s]-1,0])
                if ((request['filesize'][s]==0) and (request['value'][s]==None)): #아직 완료되지 않았던 flow가 전송이 완료되면?
                    #print ("s{}의 전송이 완료됨".format(s))
                    if (request['deadline'][s]!=0): #기간 안에 전송되면?
                        request['value'][s]=1 #value를 1로 변경
                        print ("s{}의 전송이 deadline 안에 완료됨".format(s))
                    else: #기간안에 전송된게 아니라면(value초기값은 None)
                        request['value'][s]=0
                        print ("s{}의 전송이 deadline을 지나 완료됨".format(s))
            
            yield env.timeout(Tfu) 
        elif ((fs[0]==0)and(fs[1]==0)and(fs[2]==0)):
            print ("종료:",env.now)
            return #모든 flow의 전송이 완료되면 종료
        
        
proc=env.process(flowUpdate_interval(env,action,Tfu))
env.run(until=proc)
